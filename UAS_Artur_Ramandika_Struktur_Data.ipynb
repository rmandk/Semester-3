# %% [markdown]
# <a href="https://colab.research.google.com/github/rmandk/Semester-3/blob/main/UAS_Artur_Ramandika_Struktur_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Artur Ramandika
# Npm : 20241310023

# %% [markdown]
# Soal No 1
# Tabel Data Gejala Penyakit
#
# Keterangan :
#
# 1 = YA
#
# 2 = TIDAK

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Soal No 2
#
# Model Decision Tree

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Soal no 3

# %%
print("=== SISTEM DIAGNOSA COVID-19 ===")

while True:
    print("\nMasukkan 1 = YA, 0 = TIDAK\n")

    kehilangan_penciuman = int(input("Apakah kehilangan penciuman? "))
    demam = int(input("Apakah demam? "))
    batuk = int(input("Apakah batuk? "))
    kelelahan = int(input("Apakah kelelahan? "))
    sesak_nafas = int(input("Apakah sesak nafas? "))


    if kehilangan_penciuman == 1:
        if demam == 1:
            if sesak_nafas == 1:
                diagnosa = "COVID-19"
            else:
                diagnosa = "COVID-19"
        else:
            diagnosa = "Flu"
    else:
        if batuk == 1:
            if kelelahan == 1:
                diagnosa = "Flu"
            else:
                diagnosa = "Sehat"
        else:
            diagnosa = "Sehat"

    print("\nHasil Diagnosa:")
    print("➡️", diagnosa)

    print("\nApakah ingin melakukan diagnosa lagi?")
    print("1. Ya")
    print("0. Selesai")

    pilihan = input("Pilih (1/0): ")

    if pilihan == "0":
        print("\nTerima kasih telah menggunakan sistem cek covid.")
        break
# Out:
# === SISTEM DIAGNOSA COVID-19 ===
#
# Masukkan 1 = YA, 0 = TIDAK
#
# Apakah kehilangan penciuman? 0
# Apakah demam? 0
# Apakah batuk? 0
# Apakah kelelahan? 0
# Apakah sesak nafas? 0
#
# Hasil Diagnosa:
# ➡️ Sehat
#
# Apakah ingin melakukan diagnosa lagi?
# 1. Ya
# 0. Selesai
# Pilih (1/0): 1
#
# Masukkan 1 = YA, 0 = TIDAK
#
# Apakah kehilangan penciuman? 0
# Apakah demam? 0
# Apakah batuk? 1
# Apakah kelelahan? 0
# Apakah sesak nafas? 0
#
# Hasil Diagnosa:
# ➡️ Sehat
#
# Apakah ingin melakukan diagnosa lagi?
# 1. Ya
# 0. Selesai
# Pilih (1/0): 1
#
# Masukkan 1 = YA, 0 = TIDAK
#
# Apakah kehilangan penciuman? 0
# Apakah demam? 0
# Apakah batuk? 1
# Apakah kelelahan? 1
# Apakah sesak nafas? 0
#
# Hasil Diagnosa:
# ➡️ Flu
#
# Apakah ingin melakukan diagnosa lagi?
# 1. Ya
# 0. Selesai
# Pilih (1/0): 1
#
# Masukkan 1 = YA, 0 = TIDAK
#
# Apakah kehilangan penciuman? 1
# Apakah demam? 0
# Apakah batuk? 0
# Apakah kelelahan? 0
# Apakah sesak nafas? 0
#
# Hasil Diagnosa:
# ➡️ Flu
#
# ...
